# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import datetime
                                                         
# length of run, in days
SimulatedDays = 2

# Cori-Haswell data
data = np.array([
   [ 64 ,  124.154 ,  256 ,  81.015  ],
   [ 128 ,  63.166 ,  512 ,  41.254  ],
   [ 256 ,  36.443 ,  1024 ,  24.515  ]
   ])
ice_cores=data[:,0]
ocn_cores=data[:,2]
total_cores = ice_cores + ocn_cores
ice_WCtime=data[:,1]
ocn_WCtime=data[:,3]
total_WCtime = ice_WCtime + ocn_WCtime
SYPD = SimulatedDays/365. /total_WCtime*86300
plt.plot(total_cores,SYPD,'s-')

# Cori-KNL data
data = np.array([
   [ 64 ,  541.794 ,  256 ,  224.114  ],
   [ 128 ,  281.564 ,  512 ,  121.136  ],
   [ 256 ,  157.960 ,  1024 ,  72.075  ],
   [ 512 ,  87.038 ,  2048 ,  42.514  ],
   ])
ice_cores=data[:,0]
ocn_cores=data[:,2]
total_cores = ice_cores + ocn_cores
ice_WCtime=data[:,1]
ocn_WCtime=data[:,3]
total_WCtime = ice_WCtime + ocn_WCtime
SYPD = SimulatedDays/365. /total_WCtime*86300
plt.plot(total_cores,SYPD,'^-')

# theta
data = np.array([
   [ 64 ,  1474.940 ,  512 ,  327.157  ],
   [ 128 ,  317.536 ,  1024 ,  192.335  ],
   [ 256 ,  196.357 ,  2048 ,  110.224  ],
   ])
ice_cores=data[:,0]
ocn_cores=data[:,2]
total_cores = ice_cores + ocn_cores
ice_WCtime=data[:,1]
ocn_WCtime=data[:,3]
total_WCtime = ice_WCtime + ocn_WCtime
SYPD = SimulatedDays/365. /total_WCtime*86300
plt.plot(total_cores,SYPD,'*-')

plt.legend(['Cori-Haswell','Cori-KNL','theta'],loc='upper right')
plt.xlabel('cores')
plt.ylabel('SYPD, no i/o')
date=datetime.datetime.now().strftime("%Y-%m-%d")
plt.title('ACME performance, EC60to30wLI, G case, 1:4 ice:ocn, '+date)
plt.grid(True)
plt.savefig("ACME_performance.png")
plt.show()

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import datetime
                                                         
# length of run, in days
SimulatedDays = 2

# theta
data = np.array([
   [ 64 ,  1474.940 ,  512 ,  327.157  ],
   [ 128 ,  317.536 ,  1024 ,  192.335  ],
   [ 256 ,  196.357 ,  2048 ,  110.224  ],
   ])
ice_cores=data[:,0]
ocn_cores=data[:,2]
total_cores = ice_cores + ocn_cores
ice_WCtime=data[:,1]
ocn_WCtime=data[:,3]
total_WCtime = ice_WCtime + ocn_WCtime
SYPD = SimulatedDays/365. /total_WCtime*86300
plt.plot(total_cores,SYPD,'*-')

plt.legend(['theta 1:8'],loc='upper left')
plt.xlabel('cores')
plt.ylabel('SYPD, no i/o')
date=datetime.datetime.now().strftime("%Y-%m-%d")
plt.title('ACME performance, EC60to30wLI, G case, '+date)
plt.grid(True)
plt.savefig("ACME_performance.png")
plt.show()

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import datetime
                                                         
# length of run, in days
SimulatedDays = 2

# theta
data = np.array([
   [ 128 ,  6835.674 ,  1024 ,  1898.347  ],
   [ 256 ,  3996.207 ,  2048 ,  1012.321  ],
   [ 512 ,  2327.073 ,  4096 ,  575.355  ],
   [ 1024 ,  1246.707 ,  9600 ,  299.923  ],
   ])
ice_cores=data[:,0]
ocn_cores=data[:,2]
total_cores = ice_cores + ocn_cores
ice_WCtime=data[:,1]
ocn_WCtime=data[:,3]
total_WCtime = ice_WCtime + ocn_WCtime
SYPD = SimulatedDays/365. /total_WCtime*86300
plt.plot(total_cores,SYPD,'*-')

plt.legend(['theta  1:8'],loc='upper left')
plt.xlabel('cores')
plt.ylabel('SYPD, no i/o')
date=datetime.datetime.now().strftime("%Y-%m-%d")
plt.title('ACME performance, RRS30to10, G case '+date)
plt.grid(True)
plt.savefig("ACME_performance.png")
plt.show()
